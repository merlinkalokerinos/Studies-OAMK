# %% [markdown]
# <a href="https://colab.research.google.com/github/merlinkalokerinos/Studies-OAMK/blob/main/Test_HNU_2_mit_unterscheidlichen_Agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import von urlopen & BeautifulSoup
import urllib.request as urllib2
from bs4 import BeautifulSoup
import random
from random import choice
import time

# %%
# Zielseite definieren

def urlquery(url):
    # function cycles randomly through different user agents and time intervals to simulate more natural queries
    try:
        sleeptime = float(random.randint(1,6))/5
        time.sleep(sleeptime)

        agents = ['Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1309.0 Safari/537.17',
        'Mozilla/5.0 (compatible; MSIE 10.6; Windows NT 6.1; Trident/5.0; InfoPath.2; SLCC1; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 2.0.50727) 3gpp-gba UNTRUSTED/1.0',
        'Opera/12.80 (Windows NT 5.1; U; en) Presto/2.10.289 Version/12.02',
        'Mozilla/4.0 (compatible; MSIE 5.5; Windows NT)',
        'Mozilla/3.0',
        'Mozilla/5.0 (iPhone; U; CPU like Mac OS X; en) AppleWebKit/420+ (KHTML, like Gecko) Version/3.0 Mobile/1A543a Safari/419.3',
        'Mozilla/5.0 (Linux; U; Android 0.5; en-us) AppleWebKit/522+ (KHTML, like Gecko) Safari/419.3',
        'Opera/9.00 (Windows NT 5.1; U; en)']

        agent = choice(agents)
        opener = urllib2.build_opener()
        opener.addheaders = [('User-agent', agent)]

        html = opener.open(url).read()
        time.sleep(sleeptime)
        
        return html

    except Exception as e:
        print('Something went wrong with Crawling:\n%s' % e)

# %%
news_containersall =[]
for i in range(1,8):
   
    
    url = 'https://www.hnu.de/studium/news/' +str(i) 
   
    soup = BeautifulSoup(urlquery(url), 'html.parser')
    
    news_containers =soup.findAll("li",{"class":"newslist__item"})
    
    news_containersall.append(news_containers)
    
    print(news_containersall)
# Out:
# [[<li class="newslist__item newslist__item--topnews"><div class="textmedia textmedia--teaser textmedia--colored textmedia--color-2 textmedia--teaser-in-list" itemscope="itemscope" itemtype="https://schema.org/Article"><meta content="2022-03-24" itemprop="datePublished"><a class="textmedia__teaser-title-link" href="/studium/news/detail/2022/03/24/hnu-erhaelt-daad-unterstuetzung-fuer-gruendung-einer-international-startup-league?cHash=0df08ebb3eda56a08c339e9cdf2fb751"><div class="textmedia__images"><div class="textmedia__figure textmedia__figure--offset"><div class="textmedia__liner"><img alt="" class="textmedia__image" data-alt="Illustration vieler verschiedener Menschen" data-title="Illustration vieler verschiedener Menschen" height="495" role="presentation" src="/fileadmin/_processed_/d/f/csm_UHR_Soziodemografie_834b66a324.jpeg" title="" width="840"/></div></div></div><h3 class="textmedia__teaser-title"><span class="meta"><b class="meta__date">24.03.2022</b><b class="aural">, </b><b 
# ...

# %%
from csv import writer


with open('newsHNU.csv', 'w', encoding='utf8', newline='') as f:
    thewriter = writer(f)
    header = ['Header', 'Content']
    thewriter.writerow(header)

    for i in range(0,7):
        for n in news_containersall[i]:
          
            content = n.p.text
            Header = n.h3.text
            
           
            #print("Überschrift: " + Header)
            #print("Text: " + content)
            
           
            info=[Header, content]
            thewriter.writerow(info)
